# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %cd ..
# %rm -r "Llama-2.0-architecture-and-inference-from-scratch-with-PyTorch/"
# Out:
# /kaggle/working

# %%
# !git clone "https://github.com/kaledai069/Llama-2.0-architecture-and-inference-from-scratch-with-PyTorch"
# %cd "Llama-2.0-architecture-and-inference-from-scratch-with-PyTorch/"
# Out:
# Cloning into 'Llama-2.0-architecture-and-inference-from-scratch-with-PyTorch'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 34 (delta 17), reused 25 (delta 8), pack-reused 0
# Unpacking objects: 100% (34/34), 11.65 KiB | 917.00 KiB/s, done.
# /kaggle/working/Llama-2.0-architecture-and-inference-from-scratch-with-PyTorch

# %%
# !bash download.sh
# Out:
# ...
# --2024-08-05 14:19:44--  https://download.llamameta.net/LICENSE?Policy=eyJTdGF0ZW1lbnQiOlt7InVuaXF1ZV9oYXNoIjoiZTNuZHZrb3p2ZjY2Ym93NXdrcjBtM2g5IiwiUmVzb3VyY2UiOiJodHRwczpcL1wvZG93bmxvYWQubGxhbWFtZXRhLm5ldFwvKiIsIkNvbmRpdGlvbiI6eyJEYXRlTGVzc1RoYW4iOnsiQVdTOkVwb2NoVGltZSI6MTcyMjk1Mzk0MX19fV19&Signature=D~mZbI-xMHmJ53ruEnnMPuF6ie5G3LBNdjSy~kO6PHgLJhBbCM2mZEp2kDRHUFuEmsZ2V9PDRo-4CI9ZeEZzaiD~9ymkGHkFwBTi0aJxIZEzxLM5Q2dH7hpP-5YFong4CZ6scjfAZb4LNcdrZsJ2VmmsLC2Ypyw04Ao1AbdbhqYpEOQKJ8Sdq3k1mNEZ0APRcXD8RkhFCby9cw4rx44H4hXId3YOzy0pHEeyDyQ~wACozChgpGvzM5gGNNevkK3b82io6JFmwUE4irq9ZFik2K9xs-m6lXoZ9VT6SGl5jGERsxh8z7SgWiUa8Y~tSuaQmUvyUlbhjPoSVN3jPMNoZg__&Key-Pair-Id=K15QRJLYKIFSLZ&Download-Request-ID=7519134394858148
# Resolving download.llamameta.net (download.llamameta.net)... 18.164.52.57, 18.164.52.8, 18.164.52.96, ...
# Connecting to download.llamameta.net (download.llamameta.net)|18.164.52.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !python inference.py
# Out:
# Loading Checkpoint from llama-2-7b/consolidated.00.pth !!!
# Loaded checkpoint in 45.84s
# /opt/conda/lib/python3.10/site-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
# Loaded state dictionary from checkpoint into the model in 1.53
# Generating tokens: 100%|██████████████████████| 142/142 [27:41<00:00, 11.70s/it]
# Explain the theory of relativity for a 5 year old. (I am a 5 year old)
# I am a 5 year old and my dad is trying to explain the theory of relativity to me. He says that it is all about time and space and the speed of light and how everything is relative and how I can't understand it. I am trying to understand it. I think I understand it but I need help. Please help me.
# ...
